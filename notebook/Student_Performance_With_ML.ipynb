# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('/content/drive/MyDrive/student_performance_data.csv')
df.head(10)
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
# 5              85                         81                25
# 6              83                         77                22
# 7              85                         84                13
# 8              62                         65                15
# 9              88                         90                 9
#
#    Practical Score (25%)  Exam Score (50%) Performance  Age  Gender  \
# 0                     17                33           B   21  Female
# 1                     14                26           C   25    Male
# 2                     11                35           B   19    Male
# 3                      9                19           D   24    Male
# 4                     17                19           D   21  Female
# 5                     17                38           A   18  Female
# 6                     23                14           C   25  Female
# 7                     14                35           B   18  Female
# 8                     16                16           D   22  Female
# 9                     21                23           C   19    Male
#
#   Marital Status  Children (if Married)   Mother Education   Father Education  \
# 0        Engaged                      0            College  Bachelor's Degree
# 1        Married                      0            College          Doctorate
# 2        Engaged                      0        High School          Doctorate
# 3         Single                      0        High School          Doctorate
# 4         Single                      0            College            College
# 5        Married                      2    Master's Degree          Doctorate
# 6        Married                      2  Bachelor's Degree  Bachelor's Degree
# 7        Engaged                      0  Bachelor's Degree        High School
# 8        Married                      1          Doctorate        High School
# 9        Married                      2        High School  Bachelor's Degree
#
#   Guardian (Sponsor) Extracurricular Activities  Online Time (Daily)  \
# 0              Uncle                         No                    3
# 1             Father                         No                    9
# 2             Mother                        Yes                    5
# 3            Brother                         No                    3
# 4             Sister                         No                    9
# 5            Brother                         No                    0
# 6             Mother                         No                    3
# 7             Father                         No                    2
# 8            Brother                        Yes                    8
# 9             Sister                         No                    9
#
#   Family Relationship Free Time Activities Alcoholic Consumption  \
# 0             Average          Watching TV                  High
# 1             Average          Socializing                   Low
# 2                Poor          Socializing                  High
# 3                Good               Sports              Moderate
# 4             Average               Sports                   Low
# 5                Good               Sports                  High
# 6                Good               Sports              Moderate
# 7                Poor          Watching TV                  High
# 8                Good               Sports                   Low
# 9             Average          Socializing              Moderate
#
#    Religious Programs (Weekly) Computer/Laptop Access (for Practicals)
# 0                            0                                     Yes
# 1                            5                                     Yes
# 2                            0                                     Yes
# 3                            4                                     Yes
# 4                            1                                      No
# 5                            7                                      No
# 6                            4                                      No
# 7                            0                                     Yes
# 8                            4                                      No
# 9                            2                                      No

# %% [markdown]
# # Data Processing

# %%
df.shape
# Out:
# (5000, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Attendance (%)                           5000 non-null   int64
#  1   Assignment Completion (%)                5000 non-null   int64
#  2   Test Score (25%)                         5000 non-null   int64
#  3   Practical Score (25%)                    5000 non-null   int64
#  4   Exam Score (50%)                         5000 non-null   int64
#  5   Performance                              5000 non-null   object
#  6   Age                                      5000 non-null   int64
#  7   Gender                                   5000 non-null   object
#  8   Marital Status                           5000 non-null   object
#  9   Children (if Married)                    5000 non-null   int64
#  10  Mother Education                         5000 non-null   object
#  11  Father Education                         5000 non-null   object
#  12  Guardian (Sponsor)                       5000 non-null   object
#  13  Extracurricular Activities               5000 non-null   object
#  14  Online Time (Daily)                      5000 non-null   int64
#  15  Family Relationship                      5000 non-null   object
#  16  Free Time Activities                     5000 non-null   object
#  17  Alcoholic Consumption                    5000 non-null   object
#  18  Religious Programs (Weekly)              5000 non-null   int64
#  19  Computer/Laptop Access (for Practicals)  5000 non-null   object
# dtypes: int64(9), object(11)
# memory usage: 781.4+ KB

# %%
df.describe()
# Out:
#        Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# count     5000.000000                5000.000000       5000.000000
# mean        82.863800                  82.752800         16.448200
# std         10.806341                  10.762735          5.199108
# min         21.000000                  10.000000          8.000000
# 25%         76.000000                  76.000000         12.000000
# 50%         84.000000                  84.000000         17.000000
# 75%         92.000000                  91.000000         21.000000
# max         99.000000                  99.000000         25.000000
#
#        Practical Score (25%)  Exam Score (50%)          Age  \
# count            5000.000000       5000.000000  5000.000000
# mean               16.369200         29.346000    21.476400
# std                 5.186316         12.315414     2.282649
# min                 8.000000          8.000000    18.000000
# 25%                12.000000         19.000000    19.000000
# 50%                16.000000         30.000000    21.000000
# 75%                21.000000         40.000000    23.000000
# max                25.000000         50.000000    25.000000
#
#        Children (if Married)  Online Time (Daily)  Religious Programs (Weekly)
# count            5000.000000           5000.00000                  5000.000000
# mean                0.815200              4.50760                     3.540600
# std                 1.513508              2.86419                     2.281533
# min                 0.000000              0.00000                     0.000000
# 25%                 0.000000              2.00000                     2.000000
# 50%                 0.000000              4.00000                     4.000000
# 75%                 1.000000              7.00000                     6.000000
# max                 5.000000              9.00000                     7.000000

# %%
df.isnull().sum()
# Out:
# Attendance (%)                             0
# Assignment Completion (%)                  0
# Test Score (25%)                           0
# Practical Score (25%)                      0
# Exam Score (50%)                           0
# Performance                                0
# Age                                        0
# Gender                                     0
# Marital Status                             0
# Children (if Married)                      0
# Mother Education                           0
# Father Education                           0
# Guardian (Sponsor)                         0
# Extracurricular Activities                 0
# Online Time (Daily)                        0
# Family Relationship                        0
# Free Time Activities                       0
# Alcoholic Consumption                      0
# Religious Programs (Weekly)                0
# Computer/Laptop Access (for Practicals)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)',
#        'Practical Score (25%)', 'Exam Score (50%)', 'Performance', 'Age',
#        'Gender', 'Marital Status', 'Children (if Married)', 'Mother Education',
#        'Father Education', 'Guardian (Sponsor)', 'Extracurricular Activities',
#        'Online Time (Daily)', 'Family Relationship', 'Free Time Activities',
#        'Alcoholic Consumption', 'Religious Programs (Weekly)',
#        'Computer/Laptop Access (for Practicals)'],
#       dtype='object')

# %% [markdown]
# # Remove Un-Necessary Columns

# %%
df.drop(columns=['Age','Gender','Marital Status','Children (if Married)','Guardian (Sponsor)','Computer/Laptop Access (for Practicals)','Alcoholic Consumption','Extracurricular Activities','Mother Education','Father Education','Free Time Activities','Family Relationship','Online Time (Daily)','Religious Programs (Weekly)'],inplace=True)

# %%
df.head()
# Out:
#    Attendance (%)  Assignment Completion (%)  Test Score (25%)  \
# 0              95                         86                12
# 1              78                         92                19
# 2              97                         87                23
# 3              74                         69                12
# 4              62                         74                10
#
#    Practical Score (25%)  Exam Score (50%) Performance
# 0                     17                33           B
# 1                     14                26           C
# 2                     11                35           B
# 3                      9                19           D
# 4                     17                19           D

# %%
# rename columns
df.rename(columns={'Attendance (%)':'Attendance','Assignment Completion (%)':'Assignment Completion','Test Score (25%)':'Test Score','Practical Score (25%)':'Practical Score','Exam Score (50%)':'Exam Score'},inplace=True)

# %%
df.head()
# Out:
#    Attendance  Assignment Completion  Test Score  Practical Score  Exam Score  \
# 0          95                     86          12               17          33
# 1          78                     92          19               14          26
# 2          97                     87          23               11          35
# 3          74                     69          12                9          19
# 4          62                     74          10               17          19
#
#   Performance
# 0           B
# 1           C
# 2           B
# 3           D
# 4           D

# %% [markdown]
# # Checking Uniquenes of the Columns

# %%
df['Attendance'].unique()
# Out:
# array([95, 78, 97, 74, 62, 85, 83, 88, 63, 77, 92, 67, 75, 94, 96, 86, 81,
#        91, 82, 90, 79, 89, 64, 61, 84, 76, 66, 68, 98, 72, 87, 93, 71, 70,
#        80, 65, 73, 23, 22, 99, 60, 69, 32, 30, 28, 34, 33, 25, 24, 21, 27])

# %%
df['Assignment Completion'].unique()
# Out:
# array([86, 92, 87, 69, 74, 81, 77, 84, 65, 90, 83, 91, 82, 97, 80, 94, 76,
#        98, 85, 78, 63, 67, 79, 93, 62, 96, 89, 71, 75, 88, 95, 70, 66, 99,
#        27, 38, 73, 72, 60, 68, 61, 64, 26, 10, 20, 18, 31, 30, 29, 35, 24,
#        22, 15, 37])

# %%
df['Test Score'].unique()
# Out:
# array([12, 19, 23, 10, 25, 22, 13, 15,  9, 18, 14, 11,  8, 20, 24, 17, 16,
#        21])

# %%
df['Practical Score'].unique()
# Out:
# array([17, 14, 11,  9, 23, 16, 21, 10, 22,  8, 13, 25, 15, 19, 12, 24, 18,
#        20])

# %%
df['Exam Score'].unique()
# Out:
# array([33, 26, 35, 19, 38, 14, 16, 23, 18, 12, 46, 34, 32, 22, 43, 39, 49,
#        29, 20, 24, 36, 37,  8, 42, 21, 17, 30, 31, 48, 44, 25, 50, 40, 13,
#        27, 41,  9, 10, 28, 45, 15, 11, 47])

# %%
df['Performance'].unique()
# Out:
# array(['B', 'C', 'D', 'A', 'E', 'F'], dtype=object)

# %%
# Human-readable data save karo (dataset preview ke liye)
df.to_csv('clean_student.csv', index=False)

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
# 1. Distribution of Attendance
plt.figure(figsize=(8,5))
sns.histplot(df['Attendance'],bins=10,kde=True)
plt.title('Distribution of Attendance')
plt.xlabel('Attendance')
plt.ylabel('Frequecy')
plt.show()

# %%
# 2. Distribution of Assignment Completion
plt.figure(figsize=(8,5))
sns.histplot(df['Assignment Completion'],bins=10,kde=True)
plt.title('Distribution of Assignment Completion')
plt.xlabel('Assignment Completion')
plt.ylabel('Frequency')
plt.show()

# %%
plt.title("Pyplot For Performance")
plt.pie(df['Performance'].value_counts(),labels=['A', 'B', 'C', 'D', 'E', 'F'],autopct='%0.2f')
plt.show()

# %%
# 4. Practical Score vs. Exam Score (by Performance)
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Practical Score', y='Exam Score', hue='Performance', s=100)
plt.title("Practical Score vs Exam Score (by Performance)")
plt.xlabel("Practical Score")
plt.ylabel("Exam Score")
plt.legend(title="Performance")
plt.show()

# %%
# 5. Exam Score (50%) by Performance Grade
plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='Performance', y='Exam Score')
plt.title("Exam Score  by Performance Grade")
plt.xlabel("Performance Grade")
plt.ylabel("Exam Score")
plt.show()

# %%
# 1. Bar plot for Average Scores by Performance
plt.figure(figsize=(10, 6))
df.groupby('Performance').mean().plot(kind='bar', stacked=False, colormap='viridis')
plt.title("Average Scores by Performance Grade")
plt.xlabel("Performance Grade")
plt.ylabel("Average Scores")
plt.show()

# %%
# 5. Violin plot of each column by Performance
columns = ['Attendance', 'Assignment Completion', 'Test Score', 'Practical Score', 'Exam Score']
for col in columns:
    plt.figure(figsize=(8, 5))
    sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
    plt.title(f"{col} Distribution by Performance")
    plt.xlabel("Performance")
    plt.ylabel(col)
    plt.show()
# Out:
# /tmp/ipython-input-1406304439.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# /tmp/ipython-input-1406304439.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# /tmp/ipython-input-1406304439.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# /tmp/ipython-input-1406304439.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')
# /tmp/ipython-input-1406304439.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Performance', y=col, palette='Set2')

# %%
# 8. Strip plot for each column vs Performance
for col in columns:
    plt.figure(figsize=(8, 5))
    sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
    plt.title(f"{col} vs Performance (Strip Plot)")
    plt.xlabel("Performance")
    plt.ylabel(col)
    plt.show()
# Out:
# /tmp/ipython-input-1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# /tmp/ipython-input-1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# /tmp/ipython-input-1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# /tmp/ipython-input-1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')
# /tmp/ipython-input-1453589246.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=df, x='Performance', y=col, jitter=0.2, palette='muted')

# %%
# 3. Pair plot to show relationships between columns and Performance
sns.pairplot(df, hue='Performance', palette='coolwarm', markers=["o", "s", "D", "^"])
plt.suptitle("Pair Plot of Scores with Performance", y=1.02)
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.12/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (4) than needed (6) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)

# %% [markdown]
# # Data Encoding

# %%
df.head(10)
# Out:
#    Attendance  Assignment Completion  Test Score  Practical Score  Exam Score  \
# 0          95                     86          12               17          33
# 1          78                     92          19               14          26
# 2          97                     87          23               11          35
# 3          74                     69          12                9          19
# 4          62                     74          10               17          19
# 5          85                     81          25               17          38
# 6          83                     77          22               23          14
# 7          85                     84          13               14          35
# 8          62                     65          15               16          16
# 9          88                     90           9               21          23
#
#   Performance
# 0           B
# 1           C
# 2           B
# 3           D
# 4           D
# 5           A
# 6           C
# 7           B
# 8           D
# 9           C

# %%
# ordinal encoding library
from sklearn.preprocessing import OrdinalEncoder

# %%
Performance_order = ['F','E','D','C','B','A']
oe=OrdinalEncoder(categories=[Performance_order])

# %%
df['Performance'] = oe.fit_transform(df[['Performance']])

# %%
# Transformed dataframe
df.head()
# Out:
#    Attendance  Assignment Completion  Test Score  Practical Score  Exam Score  \
# 0          95                     86          12               17          33
# 1          78                     92          19               14          26
# 2          97                     87          23               11          35
# 3          74                     69          12                9          19
# 4          62                     74          10               17          19
#
#    Performance
# 0          4.0
# 1          3.0
# 2          4.0
# 3          2.0
# 4          2.0

# %% [markdown]
# # Checking The Co-Relation Percentage Betweens Columns

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True)
plt.title('Heatmap for Checking Co-Relation')
# Out:
# Text(0.5, 1.0, 'Heatmap for Checking Co-Relation')

# %% [markdown]
# # Train & Test Data Separation

# %%
x = df.drop(columns=['Performance'])
y = df['Performance']

# %%
x
# Out:
#       Attendance  Assignment Completion  Test Score  Practical Score  \
# 0             95                     86          12               17
# 1             78                     92          19               14
# 2             97                     87          23               11
# 3             74                     69          12                9
# 4             62                     74          10               17
# ...          ...                    ...         ...              ...
# 4995          83                     86          13                9
# 4996          88                     92          17               11
# 4997          93                     85          10               11
# 4998          97                     77          21               22
# 4999          91                     87          21               13
#
#       Exam Score
# 0             33
# 1             26
# 2             35
# 3             19
# 4             19
# ...          ...
# 4995          29
# 4996          31
# 4997          31
# 4998          42
# 4999          48
#
# [5000 rows x 5 columns]

# %%
y
# Out:
# 0       4.0
# 1       3.0
# 2       4.0
# 3       2.0
# 4       2.0
#        ...
# 4995    3.0
# 4996    3.0
# 4997    3.0
# 4998    5.0
# 4999    5.0
# Name: Performance, Length: 5000, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Data Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 8.35263318e-01,  1.92075666e-01,  8.77271982e-01,
#         -7.61157843e-02,  8.58363056e-01],
#        [ 7.42448548e-01,  1.30757863e+00,  4.93093317e-01,
#          3.08064830e-01, -3.86958596e-02],
#        [ 3.71189469e-01, -4.58634394e-01,  6.85182649e-01,
#         -2.68206092e-01,  1.34766792e+00],
#        ...,
#        [-5.56958231e-01, -8.68000740e-02, -6.59442679e-01,
#          1.26851637e+00,  2.05956572e-01],
#        [-5.56958231e-01,  9.35744306e-01, -8.51532011e-01,
#          8.84335753e-01,  1.51076954e+00],
#        [-6.96110774e-05, -8.68000740e-02,  1.26145065e+00,
#         -6.52386706e-01, -8.54203965e-01]])

# %%
x_test
# Out:
# array([[-0.55695823,  1.40053721, -1.42780001, -0.07611578,  0.28750738],
#        [-0.46414346,  0.37799283,  1.45353998,  0.50015514, -0.60955153],
#        [-0.74258777,  0.37799283, -0.65944268, -1.03656732,  0.04285495],
#        ...,
#        [ 0.18555993,  1.12166147,  1.26145065, -0.84447701, -1.01730559],
#        [-0.27851392,  0.19207567,  1.26145065, -0.26820609,  1.67387116],
#        [-0.83540254, -0.83046871, -1.61988934, -1.42074794, -0.44644991]])

# %%
y_train
# Out:
# 4227    5.0
# 4676    4.0
# 800     5.0
# 3671    3.0
# 4193    5.0
#        ...
# 4426    4.0
# 466     5.0
# 3092    4.0
# 3772    5.0
# 860     3.0
# Name: Performance, Length: 4000, dtype: float64

# %%
y_test
# Out:
# 1501    3.0
# 2586    4.0
# 2653    3.0
# 1055    3.0
# 705     3.0
#        ...
# 4711    5.0
# 2313    5.0
# 3214    3.0
# 2732    5.0
# 1926    2.0
# Name: Performance, Length: 1000, dtype: float64

# %% [markdown]
# # Model & Evaluation

# %% [markdown]
# **Model List**

# %% [markdown]
# 1. RandomForest Classifier
# 2. Bagging Classifier
# 3. ExtraTrees Classifier
# 4. XGB Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from xgboost import XGBClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# %%
rfc = RandomForestClassifier()
bgc = BaggingClassifier()
etc = ExtraTreesClassifier()
xgc = XGBClassifier()

# %%
classifiers = {
    'RFC': rfc,
    'BGC': bgc,
    'ETC': etc,
    'XGC': xgc
}

# %%
# Define train_classifier function with confusion matrix display and additional metrics
def train_classifier(classifier,x_train,y_train,x_test,y_test,name):
  # Train the classifier
  classifier.fit(x_train,y_train)

  # Make predictions
  y_pred = classifier.predict(x_test)

  # Calculate metrics
  accuracy = accuracy_score(y_test,y_pred)
  precision = precision_score(y_test,y_pred, average='weighted')
  recall = recall_score(y_test,y_pred,average='weighted')
  f1 = f1_score(y_test,y_pred,average='weighted')

  # Generate and Display confusion matrix
  cm = confusion_matrix(y_test,y_pred)
  disp = ConfusionMatrixDisplay(confusion_matrix=cm)
  disp.plot(cmap=plt.cm.Blues)

  plt.title(f"Confusion Matrix for {name}")
  plt.xlabel("Predicted Labels")
  plt.ylabel("True Labels")
  plt.show()

  return accuracy, precision, recall, f1

# %%
# Lists to store accuracy, precision, recall, and F1 scores
accuracy_scores = []
precision_scores = []
recall_scores = []
f1_scores = []

# Loop through each classifier
for name,clf in classifiers.items():
  # Check if clf is a class and instantiate it if it is XGBClassifier
  if name == 'XGC' and isinstance(clf, type):
      clf = clf() # Instantiate the class

  # Train the Classifier, get metrics, and Display Confusion matrix
  current_accuracy, current_precision, current_recall, current_f1 = train_classifier(clf,x_train,y_train,x_test,y_test,name)

  # Print the Classifier's performance metrics
  print(f"Name : {name}")
  print(f"Accuracy : {current_accuracy}")
  print(f"Precision : {current_precision}")
  print(f"Recall : {current_recall}")
  print(f"F1 : {current_f1}")
  print('----------------------------------')

  # Append scores to the lists
  accuracy_scores.append(current_accuracy)
  precision_scores.append(current_precision)
  recall_scores.append(current_recall)
  f1_scores.append(current_f1)
# Out:
# Name : RFC
# Accuracy : 0.939
# Precision : 0.9398745484183944
# Recall : 0.939
# F1 : 0.9389914562048485
# ----------------------------------
# Name : BGC
# Accuracy : 0.93
# Precision : 0.9310028364647499
# Recall : 0.93
# F1 : 0.9302843737276605
# ----------------------------------
# Name : ETC
# Accuracy : 0.94
# Precision : 0.9408141420211005
# Recall : 0.94
# F1 : 0.9398698684157674
# ----------------------------------
# Name : XGC
# Accuracy : 0.944
# Precision : 0.9446996694178121
# Recall : 0.944
# F1 : 0.9442572909150995
# ----------------------------------

# %%
performance_df=pd.DataFrame({'Algorithm':classifiers.keys(),'Accuracy':accuracy_scores,'Precision':precision_scores,'Recall':recall_scores,'F1':f1_scores})
performance_df
# Out:
#   Algorithm  Accuracy  Precision  Recall        F1
# 0       RFC     0.939   0.939875   0.939  0.938991
# 1       BGC     0.930   0.931003   0.930  0.930284
# 2       ETC     0.940   0.940814   0.940  0.939870
# 3       XGC     0.944   0.944700   0.944  0.944257

# %%
performance_df1=pd.melt(performance_df,id_vars='Algorithm')
performance_df1
# Out:
#    Algorithm   variable     value
# 0        RFC   Accuracy  0.939000
# 1        BGC   Accuracy  0.930000
# 2        ETC   Accuracy  0.940000
# 3        XGC   Accuracy  0.944000
# 4        RFC  Precision  0.939875
# 5        BGC  Precision  0.931003
# 6        ETC  Precision  0.940814
# 7        XGC  Precision  0.944700
# 8        RFC     Recall  0.939000
# 9        BGC     Recall  0.930000
# 10       ETC     Recall  0.940000
# 11       XGC     Recall  0.944000
# 12       RFC         F1  0.938991
# 13       BGC         F1  0.930284
# 14       ETC         F1  0.939870
# 15       XGC         F1  0.944257

# %% [markdown]
# # Accuacy Graphs For Each Algorithm

# %%
sns.catplot(x='Algorithm',y='value',hue='variable',data=performance_df1,kind='bar',height=5)
plt.ylim(0,1)
plt.xticks(rotation='vertical')
plt.show()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1

# %%
from sklearn.pipeline import make_pipeline
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
import joblib
from sklearn.preprocessing import StandardScaler, OrdinalEncoder
import pandas as pd

# --- Start: Data loading and preprocessing for x and y ---
# Reload the original dataset to ensure 'df' is defined and in the expected state
df = pd.read_csv('/content/drive/MyDrive/student_performance_data.csv')

# Drop unnecessary columns as per previous notebook state (cell hvOdQqGv13WA)
df.drop(columns=['Age','Gender','Marital Status','Children (if Married)','Guardian (Sponsor)','Computer/Laptop Access (for Practicals)','Alcoholic Consumption','Extracurricular Activities','Mother Education','Father Education','Free Time Activities','Family Relationship','Online Time (Daily)','Religious Programs (Weekly)'],inplace=True)

# Rename columns as per previous notebook state (cell NxKIm0Ml3VUx)
df.rename(columns={'Attendance (%)':'Attendance','Assignment Completion (%)':'Assignment Completion','Test Score (25%)':'Test Score','Practical Score (25%)':'Practical Score','Exam Score (50%)':'Exam Score'},inplace=True)

# Ordinal encode 'Performance' column as per previous notebook state (cells lwnWHEmXClu2, atl6tssPDXF7)
performance_order = ['F','E','D','C','B','A']
oe = OrdinalEncoder(categories=[performance_order])
df['Performance'] = oe.fit_transform(df[['Performance']])
# --- End: Data loading and preprocessing for x and y ---

# Re-creating x and y from the processed df
x = df.drop(columns=['Performance'])
y = df['Performance']

# Original (unscaled) x, y se dobara split karo — naye naam se
x_train_raw, x_test_raw, y_train_final, y_test_final = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# Pipeline banao: scaler + model dono ek sath
final_model = make_pipeline(StandardScaler(), XGBClassifier())

# Fit karo
final_model.fit(x_train_raw, y_train_final)

# Test karo
y_pred_final = final_model.predict(x_test_raw)
print("Final Model Accuracy:", accuracy_score(y_test_final, y_pred_final))

# Save karo
joblib.dump(final_model, 'student_performance_pipeline.pkl')

# Clean data bhi save karo (dropdown/stats ke liye)
# This part reloads the original data and performs a different set of cleaning
# (column selection and renaming) for a different purpose (dropdown/stats),
# which is distinct from the 'df' used for model training. This is kept as is.
df_original = pd.read_csv('/content/drive/MyDrive/student_performance_data.csv')
df_original = df_original[['Attendance (%)', 'Assignment Completion (%)', 'Test Score (25%)',
                            'Practical Score (25%)', 'Exam Score (50%)', 'Performance']]
df_original.columns = ['Attendance', 'Assignment Completion', 'Test Score',
                        'Practical Score', 'Exam Score', 'Performance']
df_original.to_csv('clean_student.csv', index=False)

# Download karo
from google.colab import files
files.download('student_performance_pipeline.pkl')
files.download('clean_student.csv')
# Out:
# Final Model Accuracy: 0.949
